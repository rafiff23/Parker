# %%
import pandas as pd

# %%
df = pd.read_csv('leads_clean.csv')

# %%
df
# Out:
#     Unnamed: 0  No Jenis Pekerjaan                     Nama Calon Klien  \
# 0            0   1   DUE DILIGENCE                 PT ABM Investama Tbk
# 1            1   2           AUDIT  PT Globalization Partners Indonesia
# 2            2   3           AUDIT     PT Sany Heavy Industry Indonesia
# 3            3   4           AUDIT    PT Sany Indonesia Heavy Equipment
# 4            4   5           AUDIT          PT Sany Indonesia Machinery
# ..         ...  ..             ...                                  ...
# 92          92  93      CONSULTING                                 ITDC
# 93          93  94      CONSULTING               PT PLN Indonesia Power
# 94          94  95      CONSULTING                            PT Taspen
# 95          95  96      CONSULTING                       Perum Perumnas
# 96          96  97           AUDIT                              Batumbu
#
#                             Detail Pekerjaan        Fee  \
# ...

# %%
df = df.rename(columns = {'confirmed/not confirmed' : 'Status', '  Fee' : 'Fee'})
df.drop(columns='No', axis=1, inplace=True)

# %%
df['Fee'] = df['Fee'].str.replace('Rp', '', regex=True)
df['Fee'] = df['Fee'].str.strip()
df['Fee'] = df['Fee'].str.replace(',', '', regex=True)
df['Fee'].fillna(0,inplace=True)
df['Fee'] = df['Fee'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df['Fee'] = df['Fee'].str.replace('Rp', '', regex=True)
#       2 df['Fee'] = df['Fee'].str.strip()
#       3 df['Fee'] = df['Fee'].str.replace(',', '', regex=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
# ...

# %%
count_value = df[df['Status'] == 'Confirmed']['Fee'].sum()
print(count_value)
# Out:
# 5456050000

# %%
df_count_bar = df.groupby(["Status Level", "Status"]).size().reset_index(name="Count")
df_count_bar
# Out:
#   Status Level                      Status  Count
# 0      Confirm                   Confirmed     25
# 1      Confirm               Not confirmed      1
# 2  Opportunity               Not confirmed      1
# 3  Opportunity            Pending di Klien     18
# 4  Opportunity  Proses Penyusunan Proposal      4
# 5  Opportunity                Target Fokus     11
# 6  Opportunity             To be Confirmed     10
# 7         Weak            Pending di Klien     21
# 8         Weak                Target Fokus      5
# 9         Weak             To be Confirmed      1

# %%
df1 = df.groupby('Status')['Fee'].sum().reset_index().sort_values(by = 'Fee', ascending=False)

# %%
df1
# Out:
#                             Status         Fee
# 5                     Target fokus  8750000000
# 2                 Pending di Klien  5932500000
# 0                        Confirmed  5456050000
# 6                  To be Confirmed   570000000
# 1                    Not confirmed   220000000
# 7  draf englet proses review klien    95000000
# 3       Proses Penyusunan Proposal           0
# 4                     Target Fokus           0

# %%
import altair as alt

alt.Chart(df1).mark_bar().encode(
    x=alt.X('Status', sort='-y'),
    y='Fee'
)
# Out:
# alt.Chart(...)

# %%
df2 = df.groupby('Status')['Fee'].count().reset_index().sort_values(by = 'Fee', ascending=False)

# %%
df2.rename(columns={'Fee' : 'Total Count'}, inplace=True)

# %%
import altair as alt

chart = alt.Chart(df2).mark_arc(innerRadius=50).encode(
    theta="Total Count:Q",
    color="Status:N",
    tooltip=["Status", "Total Count"]
).interactive()

chart
# Out:
# alt.Chart(...)

# %%
df.columns
# Out:
# Index(['No', 'Jenis Pekerjaan', 'Nama Calon Klien', 'Detail Pekerjaan', 'Fee',
#        'PIC', 'Status', 'Notes'],
#       dtype='object')
